# %% [markdown]
# # Uso de librerías Scipy

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import newton

x = np.linspace(-2, 4, 400)
# -2 límite inicial, 4 límite final incl., 400 número de puntos

y = f(x)

plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()

# %%
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

# %%
def f_prime(x: float, *args):  # Agregamos *args para ignorar argumentos adicionales
    return 3 * x**2 - 6 * x + 1  # Derivada de f(x)

# Configuración del método de Newton
x0 = 100
points = []  # Lista para almacenar los puntos evaluados

# Aplicación del método de Newton con la derivada
x_r = newton(f, x0, fprime=f_prime, args=(points, True), maxiter=100)

print("Raíz aproximada:", x_r)
print("Puntos evaluados:", points)
# Out:
# f(100.0) = 970099.0
# f(67.00455766810653) = 287421.5546044976
# f(45.009926065596666) = 85151.64374336696
# f(30.35039723527028) = 25223.076156622286
# f(20.582860416480248) = 7468.634520318185
# f(14.079716839009599) = 2209.5053464848224
# f(9.757835905944379) = 652.2076251031732
# f(6.898518561069087) = 191.4272950525605
# f(5.028701696557697) = 55.330187134373084
# f(3.843680657951718) = 15.30811830079546
# f(3.1559707952275144) = 3.709463570275677
# f(2.8454158843448356) = 0.593842355835478
# f(2.773143092634202) = 0.0285402881796184
# f(2.7693029596247096) = 7.838698133211253e-05
# f(2.7692923543194023) = 5.96992677515118e-10
# Raíz aproximada: 2.7692923542386314
# ...

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, y, label="$x^3 - 3x^2 + x - 1$")
plt.axhline(0, color="black", linewidth=0.5)
plt.axvline(0, color="black", linewidth=0.5)
plt.scatter(x_r, f(x_r), color="red", zorder=5)  # Add the root to the plot
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of the equation $x^3 - 3x^2 + x - 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()

# %%
# Extract x values from points
x_points = [point[0] for point in points]

# Plot the x points
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
x0 = -1
points = []  # Lista para almacenar los puntos evaluados

# Aplicación del método de Newton con la derivada
x_r = newton(f, x0, fprime=f_prime, args=(points, True), maxiter=100)

print("Raíz aproximada:", x_r)
print("Puntos evaluados:", points)
# Out:
# f(-1.0) = -6.0
# f(-0.4) = -1.9440000000000002
# f(0.10103092783505152) = -0.9285595695281881
# f(2.2887793276654564) = -2.436957853187038
# f(3.105767299013572) = 3.1259765087016476
# f(2.8291999504602514) = 0.46205275489157804
# f(2.7717158120621077) = 0.01794341645387032
# f(2.76929656115579) = 3.1094202426196205e-05
# f(2.769292354251341) = 9.39368582919542e-11
# Raíz aproximada: 2.7692923542386314
# Puntos evaluados: [(-1.0, -6.0), (-0.4, -1.9440000000000002), (0.10103092783505152, -0.9285595695281881), (2.2887793276654564, -2.436957853187038), (3.105767299013572, 3.1259765087016476), (2.8291999504602514, 0.46205275489157804), (2.7717158120621077, 0.01794341645387032), (2.76929656115579, 3.1094202426196205e-05), (2.769292354251341, 9.39368582919542e-11)]

# %%
x_points = [point[0] for point in points]

# Plot the x points
plt.figure(figsize=(8, 6))
plt.plot(x_points, "o-", label="x points")
plt.grid(color="gray", linestyle="--", linewidth=0.5)
plt.title("Plot of x points in points")
plt.xlabel("Index")
plt.ylabel("x value")
plt.legend()
plt.show()

# %%
# Definimos la función y su derivada
def f(x: float, points: list[float] = [], show: bool = False):
    y = x**3 - 3 * x**2 + x - 1
    points.append((x, y))
    if show:
        print(f"f({x}) = {y}")
    return y

def f_prime(x: float, *args):  # Añadimos *args para ignorar los argumentos extra
    return 3 * x**2 - 6 * x + 1  # Derivada de f(x)

# Punto inicial
x0 = -1
points = []  # Lista para almacenar los puntos evaluados

# Aplicación del método de Newton, especificando la derivada y obteniendo información completa
x_r, alg_info = newton(
    f,
    x0,
    fprime=f_prime,       # Añadimos la derivada para usar el método de Newton
    args=(points, False),  # Argumentos adicionales para la función `f`
    maxiter=50,
    disp=False,            # No mostrar mensajes de error cuando no converge
    full_output=True       # Devolver información adicional del algoritmo
)

print("Raíz aproximada:", x_r)
print("Información del algoritmo:", alg_info)
print("Puntos evaluados:", points)
# Out:
# Raíz aproximada: 2.7692923542386314
# Información del algoritmo:       converged: True
#            flag: converged
#  function_calls: 18
#      iterations: 9
#            root: 2.7692923542386314
#          method: newton
# Puntos evaluados: [(-1.0, -6.0), (-0.4, -1.9440000000000002), (0.10103092783505152, -0.9285595695281881), (2.2887793276654564, -2.436957853187038), (3.105767299013572, 3.1259765087016476), (2.8291999504602514, 0.46205275489157804), (2.7717158120621077, 0.01794341645387032), (2.76929656115579, 3.1094202426196205e-05), (2.769292354251341, 9.39368582919542e-11)]
