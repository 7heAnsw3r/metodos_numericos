# %% [markdown]
# # Taller [5] Gauss-Jacobi & Gauss-Seidel

# %%
# %load_ext autoreload
# %autoreload 2

from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

A = [[3,2], [2,10]]
b = [11,16]

x_jacobi, trace_jacobi = gauss_jacobi(A=A, b=b, x0=(1,1), tol=10-10, max_iter=22)
x_seidel, trace_seidel = gauss_seidel(A=A, b=b, x0=(1,1), tol=10e-6, max_iter=5)

x_exact = np.linalg.solve(A, b)

# Convertimos los traces a arrays 2D homogéneos
trace_jacobi = np.array([x.flatten() for x in trace_jacobi])
trace_seidel = np.array([x.flatten() for x in trace_seidel])

plt.figure(figsize=(8, 6))

# Graficar la evolución de Jacobi
for i in range(trace_jacobi.shape[1]):
    plt.plot(range(len(trace_jacobi)), trace_jacobi[:, i], label=f"Jacobi x_{i+1} (Iteraciones)", linestyle='-', color='blue')

# Graficar la evolución de Gauss-Seidel
for i in range(trace_seidel.shape[1]):
    plt.plot(range(len(trace_seidel)), trace_seidel[:, i], label=f"Gauss-Seidel x_{i+1} (Iteraciones)", linestyle='--', color='green')

plt.xlabel("Iteraciones")
plt.ylabel("Valor de la solución")
plt.title("Comparación entre Jacobi y Gauss-Seidel")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [01-25 08:56:12][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:56:12][INFO] i= 1 x: [[3.  1.4]]
# [01-25 08:56:12][INFO] i= 2 x: [[2.73333333 1.        ]]
# [01-25 08:56:12][INFO] i= 3 x: [[3.         1.05333333]]
# [01-25 08:56:12][INFO] i= 4 x: [[2.96444444 1.        ]]
# [01-25 08:56:12][INFO] i= 5 x: [[3.         1.00711111]]
# [01-25 08:56:12][INFO] i= 6 x: [[2.99525926 1.        ]]
# [01-25 08:56:12][INFO] i= 7 x: [[3.         1.00094815]]
# [01-25 08:56:12][INFO] i= 8 x: [[2.9993679 1.       ]]
# [01-25 08:56:12][INFO] i= 9 x: [[3.         1.00012642]]
# [01-25 08:56:12][INFO] i= 10 x: [[2.99991572 1.        ]]
# [01-25 08:56:12][INFO] i= 11 x: [[3.         1.00001686]]
# [01-25 08:56:12][INFO] i= 12 x: [[2.99998876 1.        ]]
# [01-25 08:56:12][INFO] i= 13 x: [[3.         1.00000225]]
# [01-25 08:56:12][INFO] i= 14 x: [[2.9999985 1.       ]]
# ...

# %%
# Out:
# [01-25 08:52:26][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:52:26][INFO] i= 1 x: [[3.  1.4]]
# [01-25 08:52:26][INFO] i= 2 x: [[2.73333333 1.        ]]
# [01-25 08:52:26][INFO] i= 3 x: [[3.         1.05333333]]
# [01-25 08:52:26][INFO] i= 4 x: [[2.96444444 1.        ]]
# [01-25 08:52:26][INFO] i= 5 x: [[3.         1.00711111]]
# [01-25 08:52:26][INFO] i= 6 x: [[2.99525926 1.        ]]
# [01-25 08:52:26][INFO] i= 7 x: [[3.         1.00094815]]
# [01-25 08:52:26][INFO] i= 8 x: [[2.9993679 1.       ]]
# [01-25 08:52:26][INFO] i= 9 x: [[3.         1.00012642]]
# [01-25 08:52:26][INFO] i= 10 x: [[2.99991572 1.        ]]
# [01-25 08:52:26][INFO] i= 11 x: [[3.         1.00001686]]
# [01-25 08:52:26][INFO] i= 12 x: [[2.99998876 1.        ]]
# [01-25 08:52:26][INFO] i= 13 x: [[3.         1.00000225]]
# [01-25 08:52:26][INFO] i= 14 x: [[2.9999985 1.       ]]
# [01-25 08:52:26][INFO] i= 15 x: [[3.        1.0000003]]
# [01-25 08:52:26][INFO] i= 16 x: [[2.9999998 1.       ]]
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

A = [[3,2], [2,10]]
b = [11,16]

x_jacobi, trace_jacobi = gauss_jacobi(A=A, b=b, x0=(5,-2), tol=10-10, max_iter=22)
x_seidel, trace_seidel = gauss_seidel(A=A, b=b, x0=(5,2), tol=10e-6, max_iter=5)

x_exact = np.linalg.solve(A, b)

# Convertimos los traces a arrays 2D homogéneos
trace_jacobi = np.array([x.flatten() for x in trace_jacobi])
trace_seidel = np.array([x.flatten() for x in trace_seidel])

plt.figure(figsize=(8, 6))

# Graficar la evolución de Jacobi
for i in range(trace_jacobi.shape[1]):
    plt.plot(range(len(trace_jacobi)), trace_jacobi[:, i], label=f"Jacobi x_{i+1} (Iteraciones)", linestyle='-', color='blue')

# Graficar la evolución de Gauss-Seidel
for i in range(trace_seidel.shape[1]):
    plt.plot(range(len(trace_seidel)), trace_seidel[:, i], label=f"Gauss-Seidel x_{i+1} (Iteraciones)", linestyle='--', color='green')

plt.xlabel("Iteraciones")
plt.ylabel("Valor de la solución")
plt.title("Comparación entre Jacobi y Gauss-Seidel")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [01-25 08:56:31][INFO] i= 0 x: [[ 5. -2.]]
# [01-25 08:56:31][INFO] i= 1 x: [[5.  0.6]]
# [01-25 08:56:31][INFO] i= 2 x: [[3.26666667 0.6       ]]
# [01-25 08:56:31][INFO] i= 3 x: [[3.26666667 0.94666667]]
# [01-25 08:56:31][INFO] i= 4 x: [[3.03555556 0.94666667]]
# [01-25 08:56:31][INFO] i= 5 x: [[3.03555556 0.99288889]]
# [01-25 08:56:31][INFO] i= 6 x: [[3.00474074 0.99288889]]
# [01-25 08:56:31][INFO] i= 7 x: [[3.00474074 0.99905185]]
# [01-25 08:56:31][INFO] i= 8 x: [[3.0006321  0.99905185]]
# [01-25 08:56:31][INFO] i= 9 x: [[3.0006321  0.99987358]]
# [01-25 08:56:31][INFO] i= 10 x: [[3.00008428 0.99987358]]
# [01-25 08:56:31][INFO] i= 11 x: [[3.00008428 0.99998314]]
# [01-25 08:56:31][INFO] i= 12 x: [[3.00001124 0.99998314]]
# [01-25 08:56:31][INFO] i= 13 x: [[3.00001124 0.99999775]]
# [01-25 08:56:31][INFO] i= 14 x: [[3.0000015  0.99999775]]
# ...

# %%
# %load_ext autoreload
# %autoreload 2

from src import gauss_jacobi
from src import gauss_seidel
import matplotlib.pyplot as plt

A = [[2,10], [3,2]]
b = [16,11]

x_jacobi, trace_jacobi = gauss_jacobi(A=A, b=b, x0=(1,1), tol=10-10, max_iter=22)
x_seidel, trace_seidel = gauss_seidel(A=A, b=b, x0=(1,1), tol=10e-6, max_iter=5)

x_exact = np.linalg.solve(A, b)

# Convertimos los traces a arrays 2D homogéneos
trace_jacobi = np.array([x.flatten() for x in trace_jacobi])
trace_seidel = np.array([x.flatten() for x in trace_seidel])

plt.figure(figsize=(8, 6))

# Graficar la evolución de Jacobi
for i in range(trace_jacobi.shape[1]):
    plt.plot(range(len(trace_jacobi)), trace_jacobi[:, i], label=f"Jacobi x_{i+1} (Iteraciones)", linestyle='-', color='blue')

# Graficar la evolución de Gauss-Seidel
for i in range(trace_seidel.shape[1]):
    plt.plot(range(len(trace_seidel)), trace_seidel[:, i], label=f"Gauss-Seidel x_{i+1} (Iteraciones)", linestyle='--', color='green')

plt.xlabel("Iteraciones")
plt.ylabel("Valor de la solución")
plt.title("Comparación entre Jacobi y Gauss-Seidel")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [01-25 08:58:20][INFO] i= 0 x: [[1. 1.]]
# [01-25 08:58:20][INFO] i= 1 x: [[3. 4.]]
# [01-25 08:58:20][INFO] i= 2 x: [[-12.   1.]]
# [01-25 08:58:20][INFO] i= 3 x: [[ 3.  23.5]]
# [01-25 08:58:20][INFO] i= 4 x: [[-109.5    1. ]]
# [01-25 08:58:20][INFO] i= 5 x: [[  3.   169.75]]
# [01-25 08:58:20][INFO] i= 6 x: [[-840.75    1.  ]]
# [01-25 08:58:20][INFO] i= 7 x: [[   3.    1266.625]]
# [01-25 08:58:20][INFO] i= 8 x: [[-6.325125e+03  1.000000e+00]]
# [01-25 08:58:20][INFO] i= 9 x: [[3.0000000e+00 9.4931875e+03]]
# [01-25 08:58:20][INFO] i= 10 x: [[-4.74579375e+04  1.00000000e+00]]
# [01-25 08:58:20][INFO] i= 11 x: [[3.00000000e+00 7.11924062e+04]]
# [01-25 08:58:20][INFO] i= 12 x: [[-3.55954031e+05  1.00000000e+00]]
# [01-25 08:58:20][INFO] i= 13 x: [[3.00000000e+00 5.33936547e+05]]
# [01-25 08:58:20][INFO] i= 14 x: [[-2.66967473e+06  1.00000000e+00]]
# ...
